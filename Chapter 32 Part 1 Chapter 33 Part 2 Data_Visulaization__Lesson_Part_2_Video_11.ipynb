# %%
#Data cleaning using ffillna bfill methods ... solve the eq y1 and y2 then show line graph

# %% [markdown]
# ![mlstudio.png](data:image/png;base64,...)

# %% [markdown]
# ![datacln1.png](data:image/png;base64,...)

# %%
# summarize the number of unique values for each column using numpy
import pandas as pd
import numpy as np
from pandas import read_csv
# define the location of the dataset
path = '/content/sample_data/NFL.csv'
# load the dataset
df = read_csv(path)
# summarize the number of unique values in each column
print(df.nunique())
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (51) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Date           169
# GameID         974
# Drive           34
# qtr              5
# down             4
#              ...
# Win_Prob    153565
# WPA         155145
# airWPA       65714
# yacWPA       55985
# Season           4
# Length: 102, dtype: int64

# %%
df.head(10)
# Out:
#          Date      GameID  Drive  qtr  ...       WPA    airWPA    yacWPA  Season
# 0  2009-09-10  2009091000      1    1  ...  0.060758       NaN       NaN  2009.0
# 1  2009-09-10  2009091000      1    1  ...  0.004655 -0.032244  0.036899  2009.0
# 2  2009-09-10  2009091000      1    1  ... -0.040295       NaN       NaN  2009.0
# 3  2009-09-10  2009091000      1    1  ... -0.049576  0.106663 -0.156239  2009.0
# 4  2009-09-10  2009091000      1    1  ...  0.097712       NaN       NaN  2009.0
# 5  2009-09-10  2009091000      2    1  ... -0.019524       NaN       NaN  2009.0
# 6  2009-09-10  2009091000      2    1  ... -0.004427 -0.010456  0.006029  2009.0
# 7  2009-09-10  2009091000      2    1  ... -0.034663       NaN       NaN  2009.0
# 8  2009-09-10  2009091000      2    1  ...  0.026054       NaN       NaN  2009.0
# 9  2009-09-10  2009091000      3    1  ... -0.006084 -0.024526  0.018442  2009.0
#
# [10 rows x 102 columns]

# %%
df.tail(5)
# Out:
#               Date      GameID  Drive  ...    airWPA    yacWPA  Season
# 171062  2012-12-09  2012120911     20  ...       NaN       NaN  2012.0
# 171063  2012-12-09  2012120911     20  ...  0.013756  0.006056  2012.0
# 171064  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
# 171065  2012-12-09  2012120911     20  ...       NaN       NaN  2012.0
# 171066  2012-12-09  2012120911     20  ...       NaN       NaN     NaN
#
# [5 rows x 102 columns]

# %%
df.isnull().sum()
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         25562
#              ...
# Win_Prob     10489
# WPA           2352
# airWPA      105214
# yacWPA      105319
# Season           1
# Length: 102, dtype: int64

# %%
df["down"].isnull()
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 171062    False
# 171063    False
# 171064    False
# 171065    False
# 171066    False
# Name: down, Length: 171067, dtype: bool

# %%
#Sometimes missing values will be entered like .., __, — , missing, na, @,??,***, etc.

df['ydsnet'].unique()
# Out:
# array([  0,   5,   2,   4,   3,  13,  12,  21,  70,  67,   1,  -6,  10,
#         14,  17,  25,  30,   8,  16,  33,  60,  15,  56,  61,  45,  79,
#         57,  71,  19,  31,  23,  18,   7,  24,  29,  37,  38,   9,  -1,
#         11,   6,  20,  36,  39,  43,  52,  54,  22,  41,  63,  -4,  35,
#         46,  48,  73,  69,  74,  -5,  51,  55,  42,  50,  76,  82,  64,
#         -2,  44,  62,  80,  53,  34,  65,  26,  59,  68,  58,  78,  32,
#         47,  72,  75,  40,  27,  77,  66,  83,  84,  81,  -3,  -7,  86,
#         87,  28,  49,  -9, -10,  90,  91, -23,  -8, -16, -87, -12,  88,
#         89, -14, -15,  99, -11, -13,  85, -18, -20,  92,  97,  94,  95,
#         98,  96,  93, -21, -24, -17, -19, -26, -40, -32, -25, -52, -45,
#        -22, -46, -27, -83, -29, -28, -59, -55, -77, -39, -33, -54, -56,
#        -73])

# %%
df['WPA'].unique()
# Out:
# array([ 0.06075785,  0.00465498, -0.04029473, ...,  0.01981161,
#        -0.00066374, -0.01022308])

# %%
#Replace missing values with valuable data

# %%
import numpy as np

missing_values=['??','na','X','999999']
df=df.replace(missing_values,np.NaN)
df
# Out:
#               Date      GameID  Drive  ...    airWPA    yacWPA  Season
# 0       2009-09-10  2009091000      1  ...       NaN       NaN  2009.0
# 1       2009-09-10  2009091000      1  ... -0.032244  0.036899  2009.0
# 2       2009-09-10  2009091000      1  ...       NaN       NaN  2009.0
# 3       2009-09-10  2009091000      1  ...  0.106663 -0.156239  2009.0
# 4       2009-09-10  2009091000      1  ...       NaN       NaN  2009.0
# ...            ...         ...    ...  ...       ...       ...     ...
# 171062  2012-12-09  2012120911     20  ...       NaN       NaN  2012.0
# 171063  2012-12-09  2012120911     20  ...  0.013756  0.006056  2012.0
# 171064  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
# 171065  2012-12-09  2012120911     20  ...       NaN       NaN  2012.0
# 171066  2012-12-09  2012120911     20  ...       NaN       NaN     NaN
#
# [171067 rows x 102 columns]

# %% [markdown]
# Fill Missing Values
# Different ways to fill the missing values
# Mean/Median, Mode
# bfill,ffill
# interpolate
# replace

# %%
df.dtypes
# Out:
# Date         object
# GameID        int64
# Drive         int64
# qtr           int64
# down        float64
#              ...
# Win_Prob    float64
# WPA         float64
# airWPA      float64
# yacWPA      float64
# Season      float64
# Length: 102, dtype: object

# %%
df['qtr']=df['qtr'].astype("float64")
m=round(df['qtr'].mean(),2)
m
# Out:
# 2.58

# %%
df['qtr'].fillna(m,inplace=True)
df
# Out:
#               Date      GameID  Drive  ...    airWPA    yacWPA  Season
# 0       2009-09-10  2009091000      1  ...       NaN       NaN  2009.0
# 1       2009-09-10  2009091000      1  ... -0.032244  0.036899  2009.0
# 2       2009-09-10  2009091000      1  ...       NaN       NaN  2009.0
# 3       2009-09-10  2009091000      1  ...  0.106663 -0.156239  2009.0
# 4       2009-09-10  2009091000      1  ...       NaN       NaN  2009.0
# ...            ...         ...    ...  ...       ...       ...     ...
# 171062  2012-12-09  2012120911     20  ...       NaN       NaN  2012.0
# 171063  2012-12-09  2012120911     20  ...  0.013756  0.006056  2012.0
# 171064  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
# 171065  2012-12-09  2012120911     20  ...       NaN       NaN  2012.0
# 171066  2012-12-09  2012120911     20  ...       NaN       NaN     NaN
#
# [171067 rows x 102 columns]

# %% [markdown]
# bfill — backward fill — It will propagate the first observed non-null value backward.
# ffill — forward fill — it propagates the last observed non-null value forward.

# %%
df.bfill(inplace=True)
df
# Out:
#               Date      GameID  Drive  ...    airWPA    yacWPA  Season
# 0       2009-09-10  2009091000      1  ... -0.032244  0.036899  2009.0
# 1       2009-09-10  2009091000      1  ... -0.032244  0.036899  2009.0
# 2       2009-09-10  2009091000      1  ...  0.106663 -0.156239  2009.0
# 3       2009-09-10  2009091000      1  ...  0.106663 -0.156239  2009.0
# 4       2009-09-10  2009091000      1  ... -0.010456  0.006029  2009.0
# ...            ...         ...    ...  ...       ...       ...     ...
# 171062  2012-12-09  2012120911     20  ...  0.013756  0.006056  2012.0
# 171063  2012-12-09  2012120911     20  ...  0.013756  0.006056  2012.0
# 171064  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
# 171065  2012-12-09  2012120911     20  ...       NaN       NaN  2012.0
# 171066  2012-12-09  2012120911     20  ...       NaN       NaN     NaN
#
# [171067 rows x 102 columns]

# %%
df1.ffill(inplace=True)
df1
# Out:
#              Date      GameID  Drive  qtr  ...       WPA    airWPA    yacWPA  Season
# 0      2009-09-10  2009091000      1    1  ...  0.060758 -0.032244  0.036899  2009.0
# 1      2009-09-10  2009091000      1    1  ...  0.004655 -0.032244  0.036899  2009.0
# 2      2009-09-10  2009091000      1    1  ... -0.040295  0.106663 -0.156239  2009.0
# 3      2009-09-10  2009091000      1    1  ... -0.049576  0.106663 -0.156239  2009.0
# 4      2009-09-10  2009091000      1    1  ...  0.097712 -0.010456  0.006029  2009.0
# ...           ...         ...    ...  ...  ...       ...       ...       ...     ...
# 40504  2009-12-27  2009122702     11    2  ... -0.013482 -0.024149  0.056439  2009.0
# 40505  2009-12-27  2009122702     11    2  ...  0.008352 -0.024149  0.056439  2009.0
# 40506  2009-12-27  2009122702     11    2  ...  0.032290 -0.024149  0.056439  2009.0
# 40507  2009-12-27  2009122702     11    2  ... -0.011691 -0.024149  0.056439  2009.0
# ...

# %% [markdown]
# interpolate() is one of the methods to fill the missing values.

# %%
df=df.interpolate()
df
# Out:
#               Date      GameID  Drive  ...    airWPA    yacWPA  Season
# 0       2009-09-10  2009091000      1  ... -0.032244  0.036899  2009.0
# 1       2009-09-10  2009091000      1  ... -0.032244  0.036899  2009.0
# 2       2009-09-10  2009091000      1  ...  0.106663 -0.156239  2009.0
# 3       2009-09-10  2009091000      1  ...  0.106663 -0.156239  2009.0
# 4       2009-09-10  2009091000      1  ... -0.010456  0.006029  2009.0
# ...            ...         ...    ...  ...       ...       ...     ...
# 171062  2012-12-09  2012120911     20  ...  0.013756  0.006056  2012.0
# 171063  2012-12-09  2012120911     20  ...  0.013756  0.006056  2012.0
# 171064  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
# 171065  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
# 171066  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
#
# [171067 rows x 102 columns]

# %%
import seaborn as sns
sns.pointplot(x='down',y='qtr',data=df,color='blue')

# %% [markdown]
# Drop Missing Values
# Removing all the null values in the dataset

# %%
df.dropna(subset=['SideofField'])
# Out:
#               Date      GameID  Drive  ...    airWPA    yacWPA  Season
# 0       2009-09-10  2009091000      1  ... -0.032244  0.036899  2009.0
# 1       2009-09-10  2009091000      1  ... -0.032244  0.036899  2009.0
# 2       2009-09-10  2009091000      1  ...  0.106663 -0.156239  2009.0
# 3       2009-09-10  2009091000      1  ...  0.106663 -0.156239  2009.0
# 4       2009-09-10  2009091000      1  ... -0.010456  0.006029  2009.0
# ...            ...         ...    ...  ...       ...       ...     ...
# 171062  2012-12-09  2012120911     20  ...  0.013756  0.006056  2012.0
# 171063  2012-12-09  2012120911     20  ...  0.013756  0.006056  2012.0
# 171064  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
# 171065  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
# 171066  2012-12-09  2012120911     20  ... -0.007079  0.006416  2012.0
#
# [171067 rows x 102 columns]

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
#Graph x values and y values

# %%
x = [10,20,30,10,50,36]
# corresponding y axis values
y = [20,40,100,10,85,45]
 
# plotting the points
plt.plot(x, y)
 
# naming the x axis
plt.xlabel('Sales-->')
# naming the y axis
plt.ylabel('Year-->')
 
# giving a title to my graph
plt.title('First Data Visulaization Fraph...')
 
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# x axis values
x = [1,2,3,4,5,6]
# corresponding y axis values
y = [2,4,1,5,2,6]
 
# plotting the points
plt.plot(x, y, color='yellow', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='red', markersize=12)
 
# setting x and y axis range
plt.ylim(0,8)
plt.xlim(0,8)
 
# naming the x axis
plt.xlabel('Time-->')
# naming the y axis
plt.ylabel('Speed-->')
 
# giving a title to my graph
plt.title('Physics graphs...')
 
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1,2,8]
y=[8,9,10]

# %%
plt.xlabel('Sales--->')
plt.ylabel('Year--->')
plt.xlim(0,10)
plt.ylim(0,100)
plt.title("Sachin")

plt.plot(x,y,color="green",linestyle='dashed',linewidth=3,marker='*',markerfacecolor='blue',markersize=20)

# %%
plt

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Columns: 102 entries, Date to Season
# dtypes: float64(54), int64(11), object(37)
# memory usage: 8.1+ KB
# None

# %%
df.head()
# Out:
#          Date      GameID  Drive  qtr  ...       WPA    airWPA    yacWPA  Season
# 0  2009-09-10  2009091000      1  1.0  ...  0.060758 -0.032244  0.036899  2009.0
# 1  2009-09-10  2009091000      1  1.0  ...  0.004655 -0.032244  0.036899  2009.0
# 2  2009-09-10  2009091000      1  1.0  ... -0.040295  0.106663 -0.156239  2009.0
# 3  2009-09-10  2009091000      1  1.0  ... -0.049576  0.106663 -0.156239  2009.0
# 4  2009-09-10  2009091000      1  1.0  ...  0.097712 -0.010456  0.006029  2009.0
#
# [5 rows x 102 columns]

# %%
df.head(10)
# Out:
#          Date      GameID  Drive  qtr  ...       WPA    airWPA    yacWPA  Season
# 0  2009-09-10  2009091000      1  1.0  ...  0.060758 -0.032244  0.036899  2009.0
# 1  2009-09-10  2009091000      1  1.0  ...  0.004655 -0.032244  0.036899  2009.0
# 2  2009-09-10  2009091000      1  1.0  ... -0.040295  0.106663 -0.156239  2009.0
# 3  2009-09-10  2009091000      1  1.0  ... -0.049576  0.106663 -0.156239  2009.0
# 4  2009-09-10  2009091000      1  1.0  ...  0.097712 -0.010456  0.006029  2009.0
# 5  2009-09-10  2009091000      2  1.0  ... -0.019524 -0.010456  0.006029  2009.0
# 6  2009-09-10  2009091000      2  1.0  ... -0.004427 -0.010456  0.006029  2009.0
# 7  2009-09-10  2009091000      2  1.0  ... -0.034663 -0.024526  0.018442  2009.0
# 8  2009-09-10  2009091000      2  1.0  ...  0.026054 -0.024526  0.018442  2009.0
# 9  2009-09-10  2009091000      3  1.0  ... -0.006084 -0.024526  0.018442  2009.0
#
# [10 rows x 102 columns]

# %%
df.tail()
# Out:
#          Date      GameID  Drive  qtr  ...       WPA    airWPA    yacWPA  Season
# 5  2009-09-10  2009091000      2  1.0  ... -0.019524 -0.010456  0.006029  2009.0
# 6  2009-09-10  2009091000      2  1.0  ... -0.004427 -0.010456  0.006029  2009.0
# 7  2009-09-10  2009091000      2  1.0  ... -0.034663 -0.024526  0.018442  2009.0
# 8  2009-09-10  2009091000      2  1.0  ...  0.026054 -0.024526  0.018442  2009.0
# 9  2009-09-10  2009091000      3  1.0  ... -0.006084 -0.024526  0.018442  2009.0
#
# [5 rows x 102 columns]

# %%
df=df.head(10)
plt.xlabel('yrdln-->')
plt.ylabel('TimeSec--->')
plt.xlim(0,50)
plt.ylim(3250,3700)
plt.title("Iris_DataSet")

plt.plot(df['yrdln'],df['TimeSecs'],color="green",linestyle='dashed',linewidth=3,marker='*',markerfacecolor='blue',markersize=20)

# %%
df=df.head(10)
plt.xlabel('yrdln-->')
plt.ylabel('TimeSec--->')
plt.xlim(0,50)
plt.ylim(3250,3700)
plt.title("Iris_DataSet")

plt.plot(df[''],df[''],color="green",linestyle='dashed',linewidth=3,marker='*',markerfacecolor='blue',markersize=20)

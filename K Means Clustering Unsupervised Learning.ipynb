# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline
X= -2 * np.random.rand(100,2)
X1 = 1 + 2 * np.random.rand(50,2)
X[50:100, :] = X1
plt.scatter(X[ : , 0], X[ :, 1], s = 50, c = 'b')
plt.show()
from sklearn.cluster import KMeans
Kmean = KMeans(n_clusters=2)
Kmean.fit(X)
Kmean.cluster_centers_
plt.scatter(X[ : , 0], X[ : , 1], s =50, c='b')
plt.scatter(-0.94665068, -0.97138368, s=200, c='g', marker='s')
plt.scatter(2.01559419, 2.02597093, s=200, c='r', marker='s')
plt.show()
Kmean.labels_
sample_test=np.array([-3.0,-3.0])
second_test=sample_test.reshape(1, -1)
Kmean.predict(second_test)
# Out:
# array([0])

# %%
plt.scatter(X[ : , 0], X[ :, 1], s = 50, c = 'b')
plt.show()

# %%
X
# Out:
# array([[-0.28183177, -1.2370401 ],
#        [-1.22743862, -0.74621101],
#        [-1.3352672 , -0.56008435],
#        [-1.80342775, -1.75429646],
#        [-1.56323289, -0.10232911],
#        [-0.41735992, -0.97282428],
#        [-1.17267446, -1.45249525],
#        [-0.28805652, -0.01703262],
#        [-1.89807037, -1.33271957],
#        [-0.70466226, -0.46495682],
#        [-1.48922081, -0.37574531],
#        [-0.42050675, -1.64572009],
#        [-1.90891286, -0.43792528],
#        [-1.14224388, -0.2725894 ],
#        [-1.67795208, -1.01196434],
#        [-0.61500507, -0.1425639 ],
#        [-1.87911701, -0.22865383],
#        [-1.73357547, -0.75092909],
#        [-0.93079614, -1.97201184],
#        [-0.50506469, -0.36088331],
#        [-0.00694202, -0.29602473],
#        [-1.42194251, -1.13176049],
#        [-0.65836097, -1.38638115],
#        [-1.39663453, -1.62606773],
#        [-1.65267644, -1.68637728],
#        [-0.34826304, -1.36350459],
#        [-1.93378076, -1.70446196],
#        [-1.81243156, -1.91953095],
#        [-1.05580369, -1.9607912 ],
#        [-1.86504758, -1.22315211],
#        [-1.32765015, -1.99915121],
#        [-1.90887808, -0.04259765],
#        [-0.13501977, -1.29739377],
#        [-0.0094152 , -0.43150629],
#        [-1.65926402, -1.54121972],
#        [-0.25153388, -1.75696275],
#        [-1.43172834, -1.29852031],
#        [-1.49048346, -0.59882481],
#        [-1.72267681, -1.86977096],
#        [-1.54882286, -0.18937011],
#        [-0.12159873, -0.56618519],
#        [-0.21364844, -1.45211987],
#        [-0.68386593, -1.18830937],
#        [-1.53059089, -0.11610497],
#        [-1.91006123, -0.48098536],
#        [-1.96397799, -1.14839186],
#        [-0.94697264, -1.40853563],
#        [-1.39550286, -0.67505112],
#        [-1.44450833, -1.60149329],
#        [-0.68195586, -1.66408152],
#        [ 1.1594532 ,  1.56920611],
#        [ 2.92216561,  2.09627649],
#        [ 2.63406752,  2.55426366],
#        [ 2.25120307,  1.83587982],
#        [ 2.70663767,  2.7781757 ],
#        [ 1.20172073,  2.31431564],
#        [ 1.16109556,  2.24232297],
#        [ 2.54317307,  1.04535444],
#        [ 1.9688694 ,  2.65448265],
#        [ 1.84636169,  1.93105032],
#        [ 2.50695064,  1.36237921],
#        [ 2.50574359,  2.32394363],
#        [ 2.99451813,  2.02175568],
#        [ 1.0655947 ,  1.89615313],
#        [ 1.32249565,  2.88829987],
#        [ 2.03512188,  1.77492529],
#        [ 2.12527631,  2.90893342],
#        [ 2.4628435 ,  1.68254769],
#        [ 2.59996414,  2.73040185],
#        [ 2.55838023,  1.63461525],
#        [ 1.50825693,  1.21922726],
#        [ 2.64903526,  1.94195902],
#        [ 2.80838425,  1.40458197],
#        [ 2.01126233,  1.99320725],
#        [ 1.52590993,  2.06749703],
#        [ 1.71837097,  1.88734324],
#        [ 2.59813673,  2.54821915],
#        [ 2.32224549,  2.38218962],
#        [ 1.00861289,  1.63764076],
#        [ 1.3814142 ,  1.09860999],
#        [ 1.51088563,  2.12061178],
#        [ 2.70274858,  2.67488155],
#        [ 1.19604285,  2.63267856],
#        [ 1.56089874,  2.35410154],
#        [ 1.14678666,  1.21585601],
#        [ 2.94794265,  1.30122389],
#        [ 2.92487881,  2.67942431],
#        [ 1.49727774,  1.07838007],
#        [ 1.44049622,  1.35271903],
#        [ 2.2859719 ,  1.87982675],
#        [ 2.08524651,  1.30605749],
#        [ 1.64220893,  2.24409672],
#        [ 2.3481148 ,  2.58745599],
#        [ 2.1987784 ,  2.50484279],
#        [ 1.86852295,  1.32178749],
#        [ 2.45661136,  1.90602533],
#        [ 2.85574416,  1.58345497],
#        [ 2.76719086,  1.13243374],
#        [ 1.50258022,  2.26931674],
#        [ 1.18003628,  2.5596282 ]])

# %%
X1 = 1 + 2 * np.random.rand(50,2)

# %%
X1
# Out:
# array([[1.72441784, 1.06446653],
#        [1.49782247, 2.63934078],
#        [1.31982373, 2.62278021],
#        [2.18801496, 1.17581547],
#        [2.26079158, 1.5100536 ],
#        [2.67709701, 1.85710281],
#        [1.94132786, 2.08513751],
#        [2.35500895, 1.93817179],
#        [1.67175135, 1.46004464],
#        [1.44936455, 2.69889313],
#        [2.6299559 , 2.48526879],
#        [2.5139217 , 2.42557282],
#        [2.10525697, 1.2756933 ],
#        [1.27325268, 2.67867637],
#        [2.95098023, 1.87411122],
#        [2.23007862, 2.65888192],
#        [1.46329562, 2.0103131 ],
#        [1.35154806, 1.54794614],
#        [1.47977001, 1.05093619],
#        [1.60771499, 2.03149193],
#        [1.07372553, 1.705968  ],
#        [2.38295983, 1.60669157],
#        [1.05331207, 2.21874106],
#        [1.96663094, 1.97853216],
#        [1.69290893, 2.72750779],
#        [2.7690252 , 1.6319087 ],
#        [2.66848967, 1.37732331],
#        [1.5983048 , 1.93916532],
#        [2.35227627, 2.85071601],
#        [1.01237613, 2.83404141],
#        [2.55734935, 1.71920444],
#        [2.40838972, 1.00045901],
#        [1.30124864, 2.28854667],
#        [2.03548294, 2.224691  ],
#        [2.04096748, 1.38939395],
#        [1.3845475 , 1.08626149],
#        [1.7036612 , 2.7034563 ],
#        [1.0828759 , 1.56697013],
#        [2.2045341 , 1.35494542],
#        [1.92217735, 2.79430087],
#        [2.37022688, 2.14967625],
#        [2.73525795, 1.29007884],
#        [1.0116352 , 1.86673898],
#        [2.84284485, 1.86653993],
#        [1.0776427 , 2.63394314],
#        [1.12840902, 2.75156503],
#        [1.87501969, 2.78903531],
#        [2.30255274, 1.53548492],
#        [1.660703  , 1.44934777],
#        [1.09845205, 2.27923442]])
